# %%
a =  564
string = 'sairam'
float = 0.564
boolean = True
print(
    int,
    string,
    boolean,
    float
)
# Out:
# 1 sairam True 0.564

# %%
#calculator

print('1.Celsius to fahrenheit')
print('2.fahrenheit to Celsius')
choice  = int(input("your choice :"))
if choice == 1:
    c = int(input('enter the celsius'))
    f = (c * 9/5)+32
    print('Celsius to Fahrenheit',f)
elif choice == 2:
    f = int(input('enter the fahrenheit value : '))
    c = (f - 32)*5/9
    print('Fahrenheit to celsius',c)
else:
    print('invalid choice')
# Out:
# 1.Celsius to fahrenheit
# 2.fahrenheit to Celsius
# Celsius to Fahrenheit 152.6

# %%
#Calculator

print('1.addition')
print('2.subtraction')
print('3.multiplication')
print('4.division')
choice  = int(input('Type of operation you want to do:'))
a = int(input("enter your value"))
b = int(input('enter your value'))
if choice == 1:
    print('\naddition of',a,'and',b,"is : ",a+b)
elif choice ==2 :
    print('\nsubtraction of',a,'and',b, "is : ",a-b)
elif choice ==3:
    print('\nmultiplication of',a,'and',b,"is : ",a*b)
elif choice == 4:
    print('\n division of',a,'and',b,"is : ",a/b)
else:
    print("\n invalid choice ")
# Out:
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
#
#  invalid choice
